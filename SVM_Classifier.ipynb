# %% [markdown]
# Demonstrate the working of SVM classifier for a suitable data set

# %%
import pandas as pd
from sklearn.svm import SVC
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix

# %%
df=pd.read_csv(r"datasets\survey lung cancer (1).csv")
df.replace('YES',1,inplace=True)
df.replace('NO',0,inplace=True)
df.replace('M',1,inplace=True)
df.replace('F',0,inplace=True)
df
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         1   69        1               2        2              1
# 1         1   74        2               1        1              1
# 2         0   59        1               1        1              2
# 3         1   63        2               2        2              1
# 4         0   63        1               2        1              1
# ..      ...  ...      ...             ...      ...            ...
# 304       0   56        1               1        1              2
# 305       1   70        2               1        1              1
# 306       1   58        2               1        1              1
# 307       1   67        2               1        2              1
# 308       1   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
lc=df['LUNG_CANCER']
lc=lc.to_numpy()
lc=lc.astype('int')
x=df.drop(['LUNG_CANCER'],axis=1)
x=x.to_numpy()

# %%
clf=SVC(kernel='linear')
clf.fit(x,lc)
pred=clf.predict(x)

# %%
report=classification_report(lc,pred,target_names=['CANCER','NO CANCER'])
print(report)
# Out:
#               precision    recall  f1-score   support
#
#       CANCER       0.77      0.69      0.73        39
#    NO CANCER       0.96      0.97      0.96       270
#
#     accuracy                           0.94       309
#    macro avg       0.86      0.83      0.85       309
# weighted avg       0.93      0.94      0.93       309

# %%
print('ACCURACY=',accuracy_score(lc,pred))
# Out:
# ACCURACY= 0.9352750809061489

# %%
tp,tn,fp,fn=confusion_matrix(lc,pred).ravel()
print('Sens=',tp/(tp+fn))
print('spec=',tn/(tn+fp))
# Out:
# Sens= 0.09342560553633218
# spec= 0.6
